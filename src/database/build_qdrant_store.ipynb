# %%
# %%capture
# %pip install langchain langchain-community qdrant-client openai langchain-core tqdm pandas -U langchain-qdrant

# %%
from langchain_community.vectorstores import Qdrant
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
import pandas as pd
import re
import os

# 📁 Paths
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
#print(f"Base Directory: {BASE_DIR}")

DATA_PATH = os.path.join(BASE_DIR, "Data", "Enriched_Indian_Startup_Dataset.csv")
#print(f"CSV Path: {DATA_PATH}")

QDRANT_LOCAL_PATH = os.path.join(BASE_DIR,"database", "qdrant_store_local_db")
#print(f"Qdrant Local Path: {QDRANT_LOCAL_PATH}")

COLLECTION_NAME = "indian_startups"

# 📊 Load and clean CSV
# Check if the file exists
if not os.path.exists(DATA_PATH):
    raise FileNotFoundError(f"The file at path '{DATA_PATH}' does not exist. Please verify the file path.")

df = pd.read_csv(DATA_PATH)
df.columns = [
    re.sub(r"[^a-zA-Z0-9_]", "", col.strip().lower().replace(" ", "_"))
    for col in df.columns
]
df = df.map(lambda x: x.strip() if isinstance(x, str) else x)

# 🧠 Prepare documents
columns_to_embed = df.columns.tolist()
docs = []
for _, row in df.iterrows():
    base_meta = row.to_dict()
    content = "\n".join(f"{col}: {row[col]}" for col in columns_to_embed if pd.notna(row[col]))
    docs.append(Document(page_content=content, metadata=base_meta))

# 🔐 Embedding model
embedding_model = OpenAIEmbeddings()



# 🔄 Load into Qdrant
qdrant_store = Qdrant.from_documents(
    documents=docs,
    embedding=embedding_model,
    path=QDRANT_LOCAL_PATH,  # ✅ Don't pass `client=`
    collection_name=COLLECTION_NAME,
    distance_func="Cosine"
)

print(f"✅ Stored {len(docs)} documents in Qdrant collection: '{COLLECTION_NAME}'")
# Out:
# Base Directory: /home/prashant-agrawal/Netflix_Project/src
# CSV Path: /home/prashant-agrawal/Netflix_Project/src/Data/Enriched_Indian_Startup_Dataset.csv
# Qdrant Local Path: /home/prashant-agrawal/Netflix_Project/src/database/qdrant_store_local_db
# ✅ Stored 500 documents in Qdrant collection: 'indian_startups'

# %%
## -- Query Qdrant Collection -- ##

from langchain_qdrant import QdrantVectorStore
from langchain_openai import OpenAIEmbeddings
from qdrant_client import QdrantClient
import os

# Define paths
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
QDRANT_LOCAL_PATH = os.path.join(BASE_DIR,"database", "qdrant_store_local_db")
#print(f"Qdrant Local Path: {QDRANT_LOCAL_PATH}")

COLLECTION_NAME = "indian_startups"

query = "Top funded fintech startups in Bengaluru"

# Create embedding model
embedding_model = OpenAIEmbeddings()

# Use the existing client instance
if client is None:
    raise ValueError("The 'client' variable is not defined. Please ensure it is initialized.")

# 🔁 Load vector store from existing collection
qdrant_store = QdrantVectorStore(
    client=client,
    collection_name=COLLECTION_NAME,
    embeddings=embedding_model,
    path=QDRANT_LOCAL_PATH,
)


# Perform search with embedding
results = qdrant_store.similarity_search_with_score(
    query=query,
    k=5,
)

# Print results
for doc, score in results:
    print(f"🧠 Score: {score:.4f}")
    print(doc.page_content)
    print("-" * 80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 25
#      22     raise ValueError("The 'client' variable is not defined. Please ensure it is initialized.")
#      24 # 🔁 Load vector store from existing collection
# ---> 25 qdrant_store = QdrantVectorStore(
#      26     client=client,
#      27     collection_name=COLLECTION_NAME,
#      28     embeddings=embedding_model,
#      29     path=QDRANT_LOCAL_PATH,
#      30 )
#      33 # Perform search with embedding
#      34 results = qdrant_store.similarity_search_with_score(
#      35     query=query,
#      36     k=5,
#      37 )
#
# TypeError: QdrantVectorStore.__init__() got an unexpected keyword argument 'embeddings'

# %%
import pandas as pd
from qdrant_client import QdrantClient
from langchain_community.vectorstores import Qdrant
from langchain_openai import OpenAIEmbeddings

# Define paths
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
QDRANT_LOCAL_PATH = os.path.join(BASE_DIR,"database", "qdrant_store_local_db")
#print(f"Qdrant Local Path: {QDRANT_LOCAL_PATH}")

COLLECTION_NAME = "indian_startups"

# Embeddings model
embedding_model = OpenAIEmbeddings()

# Sample query
query = "Tell me the names and funding of SaaS companies in Bengaluru with over ₹1000 Cr funding"

# Safe Qdrant setup
try:
    client.close()  # Close old session if exists
except:
    pass

# Initialize new client
client = QdrantClient(path=QDRANT_LOCAL_PATH)

# Load vector store
vectorstore = Qdrant(
    client=client,
    collection_name=COLLECTION_NAME,
    embeddings=embedding_model,
)

# Run semantic search
results = vectorstore.similarity_search_with_score(query, k=10)

# Print results
for i, (doc, score) in enumerate(results):
    print(f"\n🔹 Result #{i+1}")
    print(f"📄 Content:\n{doc.page_content}")
    print(f"📏 Score: {score:.4f}")

# Close client
client.close()
print("\n✅ Qdrant session closed.")
# Out:
# 🔹 Result #1
# 📄 Content:
# company_name: Freshworks
# legal_entity_type: Pvt Ltd
# state: Karnataka
# headquarters_city: Bengaluru
# year_founded: 2023
# company_website: https://davisplc.in
# logo_url: https://logo.clearbit.com/davisplc.in
# company_description_short: Synchronized cohesive application
# company_description_long: Size effect part long almost. Evening yet total economy southern family table set.
# Adult such seem.
# None artist morning hotel mouth. Stand kid case guy toward industry.
# Camera specific far field skin mean. Save hard management. Official range key. Eight everything join.
# industry_sector: AgriTech
# total_funding_raised_inr: ₹299 Cr
# number_of_funding_rounds: 2
# latest_funding_round_type: Pre-seed
# latest_funding_date: 2021-09-06
# lead_investors: Morgan Ltd
# revenue_estimate_annual: ₹276 Cr
# valuation_estimate_if_available: ₹921 Cr
# number_of_employees_current: 32
# number_of_employees_estimate_range: 319-932
# key_people: CEO: Jose Blanchard, CTO: Michael Kennedy
# founders: Isaac Smith (https://linkedin.com/in/brittanygonzales)
# board_members__advisors: Emily Hopkins
# employee_growth_yoy_: 5%
# hiring_status: Actively Hiring
# popular_roles_open: Engineering, Sales
# primary_products__services: AI Chatbot Tools
# product_categories: SaaS
# tech_stack: Node.js, MongoDB, Azure
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: SMBs
# major_customers__logos: Local Manufacturers
# press_mentions__recent_news: Color author ball stay free responsibility lawyer.
# competitors: Zoho, Salesforce
# 📏 Score: 0.7955
#
# 🔹 Result #2
# 📄 Content:
# company_name: BigBasket
# legal_entity_type: Pvt Ltd
# state: Karnataka
# headquarters_city: Chennai
# year_founded: 2009
# company_website: https://caininc.in
# logo_url: https://logo.clearbit.com/caininc.in
# company_description_short: Open-source mobile archive
# company_description_long: Among recently able event under. Respond million turn black.
# Stay particular special allow. Commercial heart man section investment along. Indicate garden quality order.
# Natural step woman husband. Law compare Mr foot author.
# industry_sector: SaaS
# total_funding_raised_inr: ₹400 Cr
# number_of_funding_rounds: 2
# latest_funding_round_type: Seed
# latest_funding_date: 2021-12-17
# lead_investors: Perez-Martinez
# revenue_estimate_annual: ₹6 Cr
# valuation_estimate_if_available: ₹1930 Cr
# number_of_employees_current: 173
# number_of_employees_estimate_range: 284-1135
# key_people: CEO: Mary Smith, CTO: Suzanne Ortega
# founders: John Williams (https://linkedin.com/in/gblair)
# board_members__advisors: Amber Russell
# employee_growth_yoy_: 41%
# hiring_status: Hiring Freeze
# popular_roles_open: Engineering, Sales
# primary_products__services: Ride Hailing
# product_categories: B2B
# tech_stack: Java, Spring Boot, GCP
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: Enterprises
# major_customers__logos: HSBC (UK), ICICI (India)
# press_mentions__recent_news: Trip degree identify talk manager power seven.
# competitors: Grofers, JioMart
# 📏 Score: 0.7952
#
# 🔹 Result #3
# 📄 Content:
# company_name: Flipkart
# legal_entity_type: LLC
# state: Punjab
# headquarters_city: Hyderabad
# year_founded: 2008
# company_website: https://ballardgroup.in
# logo_url: https://logo.clearbit.com/ballardgroup.in
# company_description_short: Multi-layered clear-thinking algorithm
# company_description_long: Answer close position soon. Ago for garden everyone year.
# Ground event expect family behavior decide. Purpose article capital continue. Past information partner enter general class.
# Card government past sure understand. Magazine only very decision person leader. Mrs tell low serious option.
# industry_sector: Edtech
# total_funding_raised_inr: ₹80 Cr
# number_of_funding_rounds: 2
# latest_funding_round_type: Series B
# latest_funding_date: 2021-09-07
# lead_investors: Warren, Gibson and Allen
# revenue_estimate_annual: ₹300 Cr
# valuation_estimate_if_available: ₹509 Cr
# number_of_employees_current: 76
# number_of_employees_estimate_range: 299-1448
# key_people: CEO: Manuel Long, CTO: Paul Bennett
# founders: John Vaughn (https://linkedin.com/in/nwhite)
# board_members__advisors: Timothy Jones
# employee_growth_yoy_: 19%
# hiring_status: Hiring Freeze
# popular_roles_open: Engineering, Sales
# primary_products__services: Electric Scooters
# product_categories: D2C
# tech_stack: Python, React, AWS
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: Enterprises
# major_customers__logos: HCL, Accenture
# press_mentions__recent_news: Chair this source against rise.
# competitors: Amazon, Meesho
# 📏 Score: 0.7951
#
# 🔹 Result #4
# 📄 Content:
# company_name: Mobikwik
# legal_entity_type: Public Ltd
# state: Punjab
# headquarters_city: Jaipur
# year_founded: 2008
# company_website: https://preston,schmidtandarcher.in
# logo_url: https://logo.clearbit.com/preston,schmidtandarcher.in
# company_description_short: Distributed bifurcated hub
# company_description_long: Good able before computer society son above. Particularly choose owner material. Through hope partner plant tell.
# Nearly computer door adult building article. Choice wide growth source if.
# Month week our ready. Through response both not education data. Opportunity source near family.
# industry_sector: Edtech
# total_funding_raised_inr: ₹193 Cr
# number_of_funding_rounds: 4
# latest_funding_round_type: Series A
# latest_funding_date: 2023-01-13
# lead_investors: Kelley-Murphy
# revenue_estimate_annual: ₹59 Cr
# valuation_estimate_if_available: ₹674 Cr
# number_of_employees_current: 301
# number_of_employees_estimate_range: 200-1335
# key_people: CEO: Mitchell Wallace, CTO: Lucas Jackson
# founders: Randy Snyder (https://linkedin.com/in/allison39)
# board_members__advisors: Sherry Moran
# employee_growth_yoy_: 50%
# hiring_status: Actively Hiring
# popular_roles_open: Marketing, Product
# primary_products__services: Prescription Medicines
# product_categories: SaaS
# tech_stack: Java, Spring Boot, GCP
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: Enterprises
# major_customers__logos: Flipkart, Tata Group
# press_mentions__recent_news: Them thought blood hard energy deep.
# competitors: Startup A, Startup B
# 📏 Score: 0.7946
#
# 🔹 Result #5
# 📄 Content:
# company_name: Flipkart
# legal_entity_type: Public Ltd
# state: Punjab
# headquarters_city: Kolkata
# year_founded: 2013
# company_website: https://rivera-grimes.in
# logo_url: https://logo.clearbit.com/rivera-grimes.in
# company_description_short: Realigned intangible encryption
# company_description_long: Fire sure special spend. Third point record message minute quality at want.
# Weight like occur seem certainly offer get none. Wrong most want wrong then. Owner kitchen measure science today remain.
# Food page debate politics true population. Eight subject sound by yard sit occur.
# industry_sector: AgriTech
# total_funding_raised_inr: ₹314 Cr
# number_of_funding_rounds: 2
# latest_funding_round_type: Series B
# latest_funding_date: 2022-01-29
# lead_investors: Hardy Group
# revenue_estimate_annual: ₹159 Cr
# valuation_estimate_if_available: ₹1705 Cr
# number_of_employees_current: 47
# number_of_employees_estimate_range: 477-839
# key_people: CEO: Rachel Davis, CTO: David White
# founders: Monica Ryan (https://linkedin.com/in/milleraudrey)
# board_members__advisors: Rhonda George
# employee_growth_yoy_: 29%
# hiring_status: Actively Hiring
# popular_roles_open: Engineering, Marketing
# primary_products__services: Online Lending
# product_categories: SaaS
# tech_stack: Java, Spring Boot, GCP
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: Enterprises
# major_customers__logos: HCL, Accenture
# press_mentions__recent_news: Bank learn article later sometimes.
# competitors: Amazon, Meesho
# 📏 Score: 0.7934
#
# 🔹 Result #6
# 📄 Content:
# company_name: Flipkart
# legal_entity_type: Pvt Ltd
# state: West Bengal
# headquarters_city: Bengaluru
# year_founded: 2020
# company_website: https://hawkinsplc.in
# logo_url: https://logo.clearbit.com/hawkinsplc.in
# company_description_short: Phased web-enabled analyzer
# company_description_long: Attack approach think ball article. Name add throughout opportunity American carry time. System eye piece growth ago know.
# Himself plan person plant economic. Subject church meeting. Single contain prove. Join song knowledge green community.
# Somebody mother food. Wish manager attack born.
# industry_sector: E-commerce
# total_funding_raised_inr: ₹234 Cr
# number_of_funding_rounds: 1
# latest_funding_round_type: Series B
# latest_funding_date: 2022-06-27
# lead_investors: Parks, Irwin and Mendez
# revenue_estimate_annual: ₹195 Cr
# valuation_estimate_if_available: ₹1356 Cr
# number_of_employees_current: 359
# number_of_employees_estimate_range: 134-1834
# key_people: CEO: Jessica Stokes, CTO: Karen Meyers
# founders: Brian Rose (https://linkedin.com/in/molly50)
# board_members__advisors: William Peters
# employee_growth_yoy_: 24%
# hiring_status: Hiring Freeze
# popular_roles_open: Product, Engineering
# primary_products__services: Online Pharmacy
# product_categories: B2B
# tech_stack: Python, React, AWS
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: SMBs
# major_customers__logos: Startups and MSMEs
# press_mentions__recent_news: Go customer tonight word discussion remain teacher.
# competitors: Amazon, Meesho
# 📏 Score: 0.7927
#
# 🔹 Result #7
# 📄 Content:
# company_name: Infosys
# legal_entity_type: Proprietorship
# state: Karnataka
# headquarters_city: Chandigarh
# year_founded: 1995
# company_website: https://luna-williams.in
# logo_url: https://logo.clearbit.com/luna-williams.in
# company_description_short: Ameliorated non-volatile database
# company_description_long: Level commercial author back skin. To what cost. Brother and issue what now like.
# There radio occur series Mrs. Term oil career force. Drop evidence report able whatever. Ok else dark quickly send thought ready.
# industry_sector: Edtech
# total_funding_raised_inr: ₹213 Cr
# number_of_funding_rounds: 1
# latest_funding_round_type: Series C
# latest_funding_date: 2022-09-05
# lead_investors: Hamilton-Stephens
# revenue_estimate_annual: ₹197 Cr
# valuation_estimate_if_available: ₹961 Cr
# number_of_employees_current: 323
# number_of_employees_estimate_range: 143-1161
# key_people: CEO: Melissa Hall, CTO: Mark Freeman
# founders: Todd Anderson (https://linkedin.com/in/william93)
# board_members__advisors: Joseph Brown
# employee_growth_yoy_: 25%
# hiring_status: Actively Hiring
# popular_roles_open: Marketing, Sales
# primary_products__services: Learning App
# product_categories: D2C
# tech_stack: Python, React, AWS
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: Enterprises
# major_customers__logos: HDFC Bank, Airtel
# press_mentions__recent_news: Degree movement laugh behavior chance role.
# competitors: Company X, Company Y
# 📏 Score: 0.7913
#
# 🔹 Result #8
# 📄 Content:
# company_name: Flipkart
# legal_entity_type: LLC
# state: Tamil Nadu
# headquarters_city: Chennai
# year_founded: 2015
# company_website: https://washington-davis.in
# logo_url: https://logo.clearbit.com/washington-davis.in
# company_description_short: Multi-tiered national matrix
# company_description_long: Want situation establish above young something. Whose read significant name.
# Have national real defense account. Major television right black and. Item response face newspaper whom. Follow one opportunity become.
# industry_sector: Logistics
# total_funding_raised_inr: ₹251 Cr
# number_of_funding_rounds: 3
# latest_funding_round_type: Series B
# latest_funding_date: 2024-05-14
# lead_investors: Wilson LLC
# revenue_estimate_annual: ₹210 Cr
# valuation_estimate_if_available: ₹927 Cr
# number_of_employees_current: 180
# number_of_employees_estimate_range: 94-876
# key_people: CEO: Christopher Rodriguez, CTO: Jamie Wilson
# founders: Crystal Bernard (https://linkedin.com/in/ifernandez)
# board_members__advisors: Stephanie Rocha
# employee_growth_yoy_: 48%
# hiring_status: Actively Hiring
# popular_roles_open: Marketing, Sales
# primary_products__services: Ride Hailing
# product_categories: SaaS
# tech_stack: Node.js, MongoDB, Azure
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: Consumers
# major_customers__logos: Direct Consumers
# press_mentions__recent_news: Cold hundred effect easy safe me.
# competitors: Amazon, Meesho
# 📏 Score: 0.7911
#
# 🔹 Result #9
# 📄 Content:
# company_name: Infosys
# legal_entity_type: Pvt Ltd
# state: Rajasthan
# headquarters_city: Delhi
# year_founded: 2019
# company_website: https://allen,morganandhayes.in
# logo_url: https://logo.clearbit.com/allen,morganandhayes.in
# company_description_short: Expanded multi-state hierarchy
# company_description_long: To single early side. Detail three plan in.
# Away keep price data true everybody standard large. Consumer data level ago degree most term evidence.
# Time couple mention street. Rule court ten but.
# Amount cut change sing fill. Similar trouble street sea go.
# industry_sector: Edtech
# total_funding_raised_inr: ₹103 Cr
# number_of_funding_rounds: 1
# latest_funding_round_type: Series B
# latest_funding_date: 2022-07-04
# lead_investors: Long, Moore and Torres
# revenue_estimate_annual: ₹250 Cr
# valuation_estimate_if_available: ₹305 Cr
# number_of_employees_current: 384
# number_of_employees_estimate_range: 99-942
# key_people: CEO: Andrew Delacruz, CTO: Denise Reyes
# founders: Brent Oconnor (https://linkedin.com/in/itorres)
# board_members__advisors: Bobby Campbell
# employee_growth_yoy_: 46%
# hiring_status: Actively Hiring
# popular_roles_open: Engineering, Product
# primary_products__services: Logistics Services
# product_categories: B2B
# tech_stack: Node.js, MongoDB, Azure
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: Enterprises
# major_customers__logos: HDFC Bank, Airtel
# press_mentions__recent_news: Lose wish not cover score truth dinner.
# competitors: Startup A, Startup B
# 📏 Score: 0.7907
#
# 🔹 Result #10
# 📄 Content:
# company_name: Mobikwik
# legal_entity_type: LLC
# state: West Bengal
# headquarters_city: Lucknow
# year_founded: 2000
# company_website: https://hughes,tapiaandwright.in
# logo_url: https://logo.clearbit.com/hughes,tapiaandwright.in
# company_description_short: Seamless national circuit
# company_description_long: Ago win major manager major. Study out glass half teacher knowledge. Movie form Mrs against take increase especially question.
# Billion east name visit. Employee remember prevent Mr question speak long. Possible pay wonder.
# industry_sector: SaaS
# total_funding_raised_inr: ₹320 Cr
# number_of_funding_rounds: 3
# latest_funding_round_type: Series C
# latest_funding_date: 2024-12-05
# lead_investors: Roth-Moore
# revenue_estimate_annual: ₹195 Cr
# valuation_estimate_if_available: ₹1822 Cr
# number_of_employees_current: 296
# number_of_employees_estimate_range: 279-1037
# key_people: CEO: Roberta Mitchell, CTO: Ralph Smith
# founders: Brendan Kline (https://linkedin.com/in/gsweeney)
# board_members__advisors: Bailey Lynch
# employee_growth_yoy_: 3%
# hiring_status: Hiring Freeze
# popular_roles_open: Marketing, Product
# primary_products__services: Online Grocery
# product_categories: B2B
# tech_stack: Node.js, MongoDB, Azure
# integrations__apis_offered: Razorpay, Zoho, Tally
# target_market: Consumers
# major_customers__logos: Direct Consumers
# press_mentions__recent_news: Personal personal wife bed break hair station cost.
# competitors: Startup A, Startup B
# 📏 Score: 0.7899
#
# ✅ Qdrant session closed.

# %%
# %%capture
# %pip install -U langchain langchain-community faiss-cpu openai langchain-openai

# %%
# -- Build full-row vector store for Indian Startup Dataset --
# This script creates a vector store from the Indian Startup Dataset, where each document represents a full row of data.
# The vector store is saved locally for later use in retrieval tasks.


import pandas as pd
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
import os

# Define base paths
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
DATA_PATH = os.path.join(BASE_DIR, "Data", "Enriched_Indian_Startup_Dataset.csv")
INDEX_PATH = os.path.join(BASE_DIR, "database","vector_store", "faiss_full_row_index" )  # 🔄 Changed the index name to reflect strategy

print(f"Base Directory: {BASE_DIR}")
print(f"Data Path: {DATA_PATH}")
print(f"Index Path: {INDEX_PATH}")
# Out:
# Base Directory: /home/prashant-agrawal/Netflix_Project/src
# Data Path: /home/prashant-agrawal/Netflix_Project/src/Data/Enriched_Indian_Startup_Dataset.csv
# Index Path: /home/prashant-agrawal/Netflix_Project/src/database/vector_store/faiss_full_row_index

# %%
def build_fullrow_vectorstore():
    df = pd.read_csv(DATA_PATH)
    docs = []

    for idx, row in df.iterrows():
        row_id = idx
        metadata = row.to_dict()

        # Join all columns into one document
        content = "\n".join(
            f"{col}: {row[col]}" for col in df.columns
            if pd.notna(row[col]) and str(row[col]).strip()
        )

        doc = Document(
            page_content=content,
            metadata={"row_id": row_id, **metadata}
        )
        docs.append(doc)

    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_documents(docs, embeddings)
    vectorstore.save_local(INDEX_PATH)

    print(f"✅ Full-row vector store created with {len(docs)} documents at: {INDEX_PATH}")

if __name__ == "__main__":
    build_fullrow_vectorstore()
# Out:
# ✅ Full-row vector store created with 500 documents at: /home/prashant-agrawal/Netflix_Project/src/database/vector_store/faiss_full_row_index

# %%
from langchain.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain.docstore.document import Document


# Paths
INDEX_DIR = "src/Data/faiss_field_chunk_index"
FAISS_INDEX_PATH = f"{INDEX_DIR}/index.faiss"
PKL_INDEX_PATH = f"{INDEX_DIR}/index.pkl"

embeddings = OpenAIEmbeddings()

# 🔁 Load existing vector store
vectorstore = FAISS.load_local(INDEX_PATH, embeddings, allow_dangerous_deserialization=True)

# 🎯 Sample query
query = "tell me the all the details of 5  related to funding in Bengaluru-based SaaS companies with over ₹1000 Cr funding"

# 🔍 Run similarity search
results = vectorstore.similarity_search_with_score(query, k=10)

# 🧪 Output test results
for i, (doc, score) in enumerate(results):
    print(f"\n🔹 Result #{i+1}")
    print(f"📄 Content:\n{doc.page_content}")
    print(f"📏 Score: {score:.4f}")
# Out:
# 🔹 Result #1
# 📄 Content:
# Company Name: Infosys
# Legal Entity Type: Pvt Ltd
# State: Rajasthan
# Headquarters City: Delhi
# Year Founded: 2019
# Company Website: https://allen,morganandhayes.in
# Logo URL: https://logo.clearbit.com/allen,morganandhayes.in
# Company Description (Short): Expanded multi-state hierarchy
# Company Description (Long): To single early side. Detail three plan in.
# Away keep price data true everybody standard large. Consumer data level ago degree most term evidence.
# Time couple mention street. Rule court ten but.
# Amount cut change sing fill. Similar trouble street sea go.
# Industry Sector: Edtech
# Total Funding Raised (INR): ₹103 Cr
# Number of Funding Rounds: 1
# Latest Funding Round Type: Series B
# Latest Funding Date: 2022-07-04
# Lead Investors: Long, Moore and Torres
# Revenue Estimate (Annual): ₹250 Cr
# Valuation Estimate (if available): ₹305 Cr
# Number of Employees (Current): 384
# Number of Employees (Estimate Range): 99-942
# Key People: CEO: Andrew Delacruz, CTO: Denise Reyes
# Founders: Brent Oconnor (https://linkedin.com/in/itorres)
# Board Members / Advisors: Bobby Campbell
# Employee Growth (YoY %): 46%
# Hiring Status: Actively Hiring
# Popular Roles Open: Engineering, Product
# Primary Products / Services: Logistics Services
# Product Categories: B2B
# Tech Stack: Node.js, MongoDB, Azure
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: HDFC Bank, Airtel
# Press Mentions / Recent News: Lose wish not cover score truth dinner.
# Competitors: Startup A, Startup B
# 📏 Score: 0.4122
#
# 🔹 Result #2
# 📄 Content:
# Company Name: Infosys
# Legal Entity Type: Proprietorship
# State: Punjab
# Headquarters City: Bengaluru
# Year Founded: 1999
# Company Website: https://johnsongroup.in
# Logo URL: https://logo.clearbit.com/johnsongroup.in
# Company Description (Short): Down-sized motivating website
# Company Description (Long): Artist gas friend tax. Probably reduce before subject sister let official apply. Ask write speech project by change training mouth.
# Paper issue pretty story stock other successful. Figure long old exist. Ground material most Republican either local.
# Industry Sector: SaaS
# Total Funding Raised (INR): ₹322 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Pre-seed
# Latest Funding Date: 2021-07-25
# Lead Investors: Dunn-Hall
# Revenue Estimate (Annual): ₹213 Cr
# Valuation Estimate (if available): ₹761 Cr
# Number of Employees (Current): 116
# Number of Employees (Estimate Range): 177-1162
# Key People: CEO: Luis Mcintosh, CTO: Chad Leonard
# Founders: Ashley Parrish (https://linkedin.com/in/gpayne)
# Board Members / Advisors: Valerie Miller
# Employee Growth (YoY %): 29%
# Hiring Status: Hiring Freeze
# Popular Roles Open: Sales, Engineering
# Primary Products / Services: Learning App
# Product Categories: B2B
# Tech Stack: Python, React, AWS
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Consumers
# Major Customers / Logos: Direct Consumers
# Press Mentions / Recent News: Total include least true research sell me pull.
# Competitors: Company X, Company Y
# 📏 Score: 0.4171
#
# 🔹 Result #3
# 📄 Content:
# Company Name: Freshworks
# Legal Entity Type: Pvt Ltd
# State: Karnataka
# Headquarters City: Bengaluru
# Year Founded: 2023
# Company Website: https://davisplc.in
# Logo URL: https://logo.clearbit.com/davisplc.in
# Company Description (Short): Synchronized cohesive application
# Company Description (Long): Size effect part long almost. Evening yet total economy southern family table set.
# Adult such seem.
# None artist morning hotel mouth. Stand kid case guy toward industry.
# Camera specific far field skin mean. Save hard management. Official range key. Eight everything join.
# Industry Sector: AgriTech
# Total Funding Raised (INR): ₹299 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Pre-seed
# Latest Funding Date: 2021-09-06
# Lead Investors: Morgan Ltd
# Revenue Estimate (Annual): ₹276 Cr
# Valuation Estimate (if available): ₹921 Cr
# Number of Employees (Current): 32
# Number of Employees (Estimate Range): 319-932
# Key People: CEO: Jose Blanchard, CTO: Michael Kennedy
# Founders: Isaac Smith (https://linkedin.com/in/brittanygonzales)
# Board Members / Advisors: Emily Hopkins
# Employee Growth (YoY %): 5%
# Hiring Status: Actively Hiring
# Popular Roles Open: Engineering, Sales
# Primary Products / Services: AI Chatbot Tools
# Product Categories: SaaS
# Tech Stack: Node.js, MongoDB, Azure
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: SMBs
# Major Customers / Logos: Local Manufacturers
# Press Mentions / Recent News: Color author ball stay free responsibility lawyer.
# Competitors: Zoho, Salesforce
# 📏 Score: 0.4172
#
# 🔹 Result #4
# 📄 Content:
# Company Name: Infosys
# Legal Entity Type: Public Ltd
# State: Karnataka
# Headquarters City: Jaipur
# Year Founded: 1995
# Company Website: https://rodriguezinc.in
# Logo URL: https://logo.clearbit.com/rodriguezinc.in
# Company Description (Short): Organized composite system engine
# Company Description (Long): Hundred market billion. Better include no a. Use support human admit.
# Interest population believe thousand. Offer across build eat mention air.
# Trouble draw Republican cultural. Others reality black.
# Industry Sector: AgriTech
# Total Funding Raised (INR): ₹345 Cr
# Number of Funding Rounds: 4
# Latest Funding Round Type: Series C
# Latest Funding Date: 2023-06-14
# Lead Investors: Johnson and Sons
# Revenue Estimate (Annual): ₹100 Cr
# Valuation Estimate (if available): ₹1922 Cr
# Number of Employees (Current): 242
# Number of Employees (Estimate Range): 484-1996
# Key People: CEO: John Mata, CTO: Amber Ramirez
# Founders: Karen Osborne (https://linkedin.com/in/brandon52)
# Board Members / Advisors: Kelly Morales
# Employee Growth (YoY %): 45%
# Hiring Status: Actively Hiring
# Popular Roles Open: Marketing, Engineering
# Primary Products / Services: Online Pharmacy
# Product Categories: D2C
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: SMBs
# Major Customers / Logos: Tier 2 Service Providers
# Press Mentions / Recent News: Movie machine particular.
# Competitors: Startup A, Startup B
# 📏 Score: 0.4225
#
# 🔹 Result #5
# 📄 Content:
# Company Name: BigBasket
# Legal Entity Type: Pvt Ltd
# State: Karnataka
# Headquarters City: Chennai
# Year Founded: 2009
# Company Website: https://caininc.in
# Logo URL: https://logo.clearbit.com/caininc.in
# Company Description (Short): Open-source mobile archive
# Company Description (Long): Among recently able event under. Respond million turn black.
# Stay particular special allow. Commercial heart man section investment along. Indicate garden quality order.
# Natural step woman husband. Law compare Mr foot author.
# Industry Sector: SaaS
# Total Funding Raised (INR): ₹400 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Seed
# Latest Funding Date: 2021-12-17
# Lead Investors: Perez-Martinez
# Revenue Estimate (Annual): ₹6 Cr
# Valuation Estimate (if available): ₹1930 Cr
# Number of Employees (Current): 173
# Number of Employees (Estimate Range): 284-1135
# Key People: CEO: Mary Smith, CTO: Suzanne Ortega
# Founders: John Williams (https://linkedin.com/in/gblair)
# Board Members / Advisors: Amber Russell
# Employee Growth (YoY %): 41%
# Hiring Status: Hiring Freeze
# Popular Roles Open: Engineering, Sales
# Primary Products / Services: Ride Hailing
# Product Categories: B2B
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: HSBC (UK), ICICI (India)
# Press Mentions / Recent News: Trip degree identify talk manager power seven.
# Competitors: Grofers, JioMart
# 📏 Score: 0.4230
#
# 🔹 Result #6
# 📄 Content:
# Company Name: Infosys
# Legal Entity Type: Pvt Ltd
# State: Maharashtra
# Headquarters City: Kolkata
# Year Founded: 2013
# Company Website: https://manning,oconnorandfreeman.in
# Logo URL: https://logo.clearbit.com/manning,oconnorandfreeman.in
# Company Description (Short): Reduced system-worthy open system
# Company Description (Long): Institution citizen watch. Avoid discussion before trial. Find wear lead hold station brother book.
# Sport itself human. Reach prevent well phone brother style address. Fill face sell prove institution cut very provide.
# More officer test western feel former. Worry kid build affect concern create.
# Industry Sector: Healthtech
# Total Funding Raised (INR): ₹274 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Pre-seed
# Latest Funding Date: 2021-10-11
# Lead Investors: Johnson, Hill and Fox
# Revenue Estimate (Annual): ₹161 Cr
# Valuation Estimate (if available): ₹120 Cr
# Number of Employees (Current): 183
# Number of Employees (Estimate Range): 464-767
# Key People: CEO: Brandon Romero, CTO: Christopher Johnson
# Founders: Thomas Jones (https://linkedin.com/in/rileytimothy)
# Board Members / Advisors: Mitchell Johnson
# Employee Growth (YoY %): 5%
# Hiring Status: Actively Hiring
# Popular Roles Open: Marketing, Engineering
# Primary Products / Services: Digital Payments
# Product Categories: D2C
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Consumers
# Major Customers / Logos: Direct Consumers
# Press Mentions / Recent News: Mr light interesting will action main computer.
# Competitors: Startup A, Startup B
# 📏 Score: 0.4237
#
# 🔹 Result #7
# 📄 Content:
# Company Name: Flipkart
# Legal Entity Type: Public Ltd
# State: Punjab
# Headquarters City: Kolkata
# Year Founded: 2013
# Company Website: https://rivera-grimes.in
# Logo URL: https://logo.clearbit.com/rivera-grimes.in
# Company Description (Short): Realigned intangible encryption
# Company Description (Long): Fire sure special spend. Third point record message minute quality at want.
# Weight like occur seem certainly offer get none. Wrong most want wrong then. Owner kitchen measure science today remain.
# Food page debate politics true population. Eight subject sound by yard sit occur.
# Industry Sector: AgriTech
# Total Funding Raised (INR): ₹314 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Series B
# Latest Funding Date: 2022-01-29
# Lead Investors: Hardy Group
# Revenue Estimate (Annual): ₹159 Cr
# Valuation Estimate (if available): ₹1705 Cr
# Number of Employees (Current): 47
# Number of Employees (Estimate Range): 477-839
# Key People: CEO: Rachel Davis, CTO: David White
# Founders: Monica Ryan (https://linkedin.com/in/milleraudrey)
# Board Members / Advisors: Rhonda George
# Employee Growth (YoY %): 29%
# Hiring Status: Actively Hiring
# Popular Roles Open: Engineering, Marketing
# Primary Products / Services: Online Lending
# Product Categories: SaaS
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: HCL, Accenture
# Press Mentions / Recent News: Bank learn article later sometimes.
# Competitors: Amazon, Meesho
# 📏 Score: 0.4255
#
# 🔹 Result #8
# 📄 Content:
# Company Name: Flipkart
# Legal Entity Type: LLC
# State: Punjab
# Headquarters City: Hyderabad
# Year Founded: 2008
# Company Website: https://ballardgroup.in
# Logo URL: https://logo.clearbit.com/ballardgroup.in
# Company Description (Short): Multi-layered clear-thinking algorithm
# Company Description (Long): Answer close position soon. Ago for garden everyone year.
# Ground event expect family behavior decide. Purpose article capital continue. Past information partner enter general class.
# Card government past sure understand. Magazine only very decision person leader. Mrs tell low serious option.
# Industry Sector: Edtech
# Total Funding Raised (INR): ₹80 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Series B
# Latest Funding Date: 2021-09-07
# Lead Investors: Warren, Gibson and Allen
# Revenue Estimate (Annual): ₹300 Cr
# Valuation Estimate (if available): ₹509 Cr
# Number of Employees (Current): 76
# Number of Employees (Estimate Range): 299-1448
# Key People: CEO: Manuel Long, CTO: Paul Bennett
# Founders: John Vaughn (https://linkedin.com/in/nwhite)
# Board Members / Advisors: Timothy Jones
# Employee Growth (YoY %): 19%
# Hiring Status: Hiring Freeze
# Popular Roles Open: Engineering, Sales
# Primary Products / Services: Electric Scooters
# Product Categories: D2C
# Tech Stack: Python, React, AWS
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: HCL, Accenture
# Press Mentions / Recent News: Chair this source against rise.
# Competitors: Amazon, Meesho
# 📏 Score: 0.4268
#
# 🔹 Result #9
# 📄 Content:
# Company Name: Infosys
# Legal Entity Type: Public Ltd
# State: Maharashtra
# Headquarters City: Bengaluru
# Year Founded: 2019
# Company Website: https://woodsandsons.in
# Logo URL: https://logo.clearbit.com/woodsandsons.in
# Company Description (Short): Managed full-range core
# Company Description (Long): Specific participant interest interesting bag. Rest simply remain cut.
# Himself attorney public character order guy.
# Possible behavior chair case from window place wall.
# Task its believe chair foot. Phone prepare skin anything.
# Industry Sector: AgriTech
# Total Funding Raised (INR): ₹258 Cr
# Number of Funding Rounds: 3
# Latest Funding Round Type: Series A
# Latest Funding Date: 2023-05-02
# Lead Investors: Torres, Washington and Joseph
# Revenue Estimate (Annual): ₹26 Cr
# Valuation Estimate (if available): ₹257 Cr
# Number of Employees (Current): 271
# Number of Employees (Estimate Range): 420-508
# Key People: CEO: Michael Mitchell, CTO: Leslie Bailey
# Founders: Cory Johnson (https://linkedin.com/in/connie42)
# Board Members / Advisors: Angela Pham
# Employee Growth (YoY %): 11%
# Hiring Status: Hiring Freeze
# Popular Roles Open: Product, Sales
# Primary Products / Services: Fashion Retail
# Product Categories: B2B
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Consumers
# Major Customers / Logos: Direct Consumers
# Press Mentions / Recent News: Product since task per figure laugh strong.
# Competitors: Company X, Company Y
# 📏 Score: 0.4279
#
# 🔹 Result #10
# 📄 Content:
# Company Name: Flipkart
# Legal Entity Type: LLC
# State: Tamil Nadu
# Headquarters City: Chennai
# Year Founded: 2015
# Company Website: https://washington-davis.in
# Logo URL: https://logo.clearbit.com/washington-davis.in
# Company Description (Short): Multi-tiered national matrix
# Company Description (Long): Want situation establish above young something. Whose read significant name.
# Have national real defense account. Major television right black and. Item response face newspaper whom. Follow one opportunity become.
# Industry Sector: Logistics
# Total Funding Raised (INR): ₹251 Cr
# Number of Funding Rounds: 3
# Latest Funding Round Type: Series B
# Latest Funding Date: 2024-05-14
# Lead Investors: Wilson LLC
# Revenue Estimate (Annual): ₹210 Cr
# Valuation Estimate (if available): ₹927 Cr
# Number of Employees (Current): 180
# Number of Employees (Estimate Range): 94-876
# Key People: CEO: Christopher Rodriguez, CTO: Jamie Wilson
# Founders: Crystal Bernard (https://linkedin.com/in/ifernandez)
# Board Members / Advisors: Stephanie Rocha
# Employee Growth (YoY %): 48%
# Hiring Status: Actively Hiring
# Popular Roles Open: Marketing, Sales
# Primary Products / Services: Ride Hailing
# Product Categories: SaaS
# Tech Stack: Node.js, MongoDB, Azure
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Consumers
# Major Customers / Logos: Direct Consumers
# Press Mentions / Recent News: Cold hundred effect easy safe me.
# Competitors: Amazon, Meesho
# 📏 Score: 0.4288

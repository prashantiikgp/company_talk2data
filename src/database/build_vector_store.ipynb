# %%
# %%capture
# %pip install -U langchain langchain-community faiss-cpu openai langchain-openai pandas

# %%
# -- Build full-row vector store for Indian Startup Dataset --
# This script creates a vector store from the Indian Startup Dataset, where each document represents a full row of data.
# The vector store is saved locally for later use in retrieval tasks.


import pandas as pd
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
import os

# Define base paths
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
DATA_PATH = os.path.join(BASE_DIR, "Data", "Enriched_Indian_Startup_Dataset.csv")
INDEX_PATH = os.path.join(BASE_DIR, "database","vector_store", "faiss_full_row_index" )  # 🔄 Changed the index name to reflect strategy

print(f"Base Directory: {BASE_DIR}")
print(f"Data Path: {DATA_PATH}")
print(f"Index Path: {INDEX_PATH}")
# Out:
# Base Directory: /home/prashant-agrawal/projects/netflix_talk2data/src
# Data Path: /home/prashant-agrawal/projects/netflix_talk2data/src/Data/Enriched_Indian_Startup_Dataset.csv
# Index Path: /home/prashant-agrawal/projects/netflix_talk2data/src/database/vector_store/faiss_full_row_index

# %%
def build_fullrow_vectorstore():
    df = pd.read_csv(DATA_PATH)
    docs = []

    for idx, row in df.iterrows():
        row_id = idx
        metadata = row.to_dict()

        # Join all columns into one document
        content = "\n".join(
            f"{col}: {row[col]}" for col in df.columns
            if pd.notna(row[col]) and str(row[col]).strip()
        )

        doc = Document(
            page_content=content,
            metadata={"row_id": row_id, **metadata}
        )
        docs.append(doc)

    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_documents(docs, embeddings)
    vectorstore.save_local(INDEX_PATH)

    print(f"✅ Full-row vector store created with {len(docs)} documents at: {INDEX_PATH}")

if __name__ == "__main__":
    build_fullrow_vectorstore()
# Out:
# ✅ Full-row vector store created with 500 documents at: /home/prashant-agrawal/projects/netflix_talk2data/src/database/vector_store/faiss_full_row_index

# %%
from langchain.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain.docstore.document import Document


# Paths
INDEX_DIR = "src/Data/faiss_field_chunk_index"
FAISS_INDEX_PATH = f"{INDEX_DIR}/index.faiss"
PKL_INDEX_PATH = f"{INDEX_DIR}/index.pkl"

embeddings = OpenAIEmbeddings()

# 🔁 Load existing vector store
vectorstore = FAISS.load_local(INDEX_PATH, embeddings, allow_dangerous_deserialization=True)

# 🎯 Sample query
query = "tell me only the 5 companies name in the fintech sector that are based in Delhi and have raised more than 10 million USD in funding"

# 🔍 Run similarity search
results = vectorstore.similarity_search_with_score(query, k=10)


# 🧪 Output test results
for i, (doc, score) in enumerate(results):
    print(f"\n🔹 Result #{i+1}")
    print(f"📄 Content:\n{doc.page_content}")
    print(f"📏 Score: {score:.4f}")
# Out:
# 🔹 Result #1
# 📄 Content:
# Company Name: Freshworks
# Legal Entity Type: Public Ltd
# State: Delhi
# Headquarters City: Ahmedabad
# Year Founded: 2019
# Company Website: https://velezllc.in
# Logo URL: https://logo.clearbit.com/velezllc.in
# Company Description (Short): Digitized upward-trending concept
# Company Description (Long): Light wind small might. Recognize from voice call issue. Must audience commercial fill stock.
# Think face lose view present. Trouble director question single impact series.
# Six already job blood bar conference. But various candidate though upon today. Change land decide almost language respond.
# Industry Sector: Healthtech
# Total Funding Raised (INR): ₹277 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Pre-seed
# Latest Funding Date: 2022-03-03
# Lead Investors: House-Kline
# Revenue Estimate (Annual): ₹35 Cr
# Valuation Estimate (if available): ₹127 Cr
# Number of Employees (Current): 269
# Number of Employees (Estimate Range): 348-547
# Key People: CEO: Brandy Mcguire, CTO: Kimberly Wilson
# Founders: Stephanie Anderson (https://linkedin.com/in/ashepherd)
# Board Members / Advisors: Paul Griffith
# Employee Growth (YoY %): 5%
# Hiring Status: Hiring Freeze
# Popular Roles Open: Sales, Marketing
# Primary Products / Services: Stock Trading App
# Product Categories: D2C
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: TCS, Infosys (India)
# Press Mentions / Recent News: Water field probably short yet.
# Competitors: Zoho, Salesforce
# 📏 Score: 0.3962
#
# 🔹 Result #2
# 📄 Content:
# Company Name: Flipkart
# Legal Entity Type: Public Ltd
# State: Punjab
# Headquarters City: Kolkata
# Year Founded: 2013
# Company Website: https://rivera-grimes.in
# Logo URL: https://logo.clearbit.com/rivera-grimes.in
# Company Description (Short): Realigned intangible encryption
# Company Description (Long): Fire sure special spend. Third point record message minute quality at want.
# Weight like occur seem certainly offer get none. Wrong most want wrong then. Owner kitchen measure science today remain.
# Food page debate politics true population. Eight subject sound by yard sit occur.
# Industry Sector: AgriTech
# Total Funding Raised (INR): ₹314 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Series B
# Latest Funding Date: 2022-01-29
# Lead Investors: Hardy Group
# Revenue Estimate (Annual): ₹159 Cr
# Valuation Estimate (if available): ₹1705 Cr
# Number of Employees (Current): 47
# Number of Employees (Estimate Range): 477-839
# Key People: CEO: Rachel Davis, CTO: David White
# Founders: Monica Ryan (https://linkedin.com/in/milleraudrey)
# Board Members / Advisors: Rhonda George
# Employee Growth (YoY %): 29%
# Hiring Status: Actively Hiring
# Popular Roles Open: Engineering, Marketing
# Primary Products / Services: Online Lending
# Product Categories: SaaS
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: HCL, Accenture
# Press Mentions / Recent News: Bank learn article later sometimes.
# Competitors: Amazon, Meesho
# 📏 Score: 0.4088
#
# 🔹 Result #3
# 📄 Content:
# Company Name: Flipkart
# Legal Entity Type: Proprietorship
# State: Uttar Pradesh
# Headquarters City: Delhi
# Year Founded: 2007
# Company Website: https://gutierrez,kennedyandavila.in
# Logo URL: https://logo.clearbit.com/gutierrez,kennedyandavila.in
# Company Description (Short): Re-contextualized foreground website
# Company Description (Long): Run man player between hundred modern tell. Officer purpose start.
# Back wonder treatment media continue one good agreement. Trip peace meeting among.
# Job nothing enjoy fly majority traditional. Side however same.
# Industry Sector: Logistics
# Total Funding Raised (INR): ₹424 Cr
# Number of Funding Rounds: 1
# Latest Funding Round Type: Series B
# Latest Funding Date: 2024-06-13
# Lead Investors: Miller-Torres
# Revenue Estimate (Annual): ₹57 Cr
# Valuation Estimate (if available): ₹1015 Cr
# Number of Employees (Current): 242
# Number of Employees (Estimate Range): 381-562
# Key People: CEO: Mark Grimes, CTO: Albert Dean
# Founders: Matthew Lewis (https://linkedin.com/in/gonzalezchristopher)
# Board Members / Advisors: Victoria Charles
# Employee Growth (YoY %): 34%
# Hiring Status: Actively Hiring
# Popular Roles Open: Product, Sales
# Primary Products / Services: Ride Hailing
# Product Categories: B2B
# Tech Stack: Python, React, AWS
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: Adani Group, Wipro
# Press Mentions / Recent News: Maybe hot now indicate military at.
# Competitors: Amazon, Meesho
# 📏 Score: 0.4090
#
# 🔹 Result #4
# 📄 Content:
# Company Name: Mobikwik
# Legal Entity Type: Public Ltd
# State: Punjab
# Headquarters City: Jaipur
# Year Founded: 2008
# Company Website: https://preston,schmidtandarcher.in
# Logo URL: https://logo.clearbit.com/preston,schmidtandarcher.in
# Company Description (Short): Distributed bifurcated hub
# Company Description (Long): Good able before computer society son above. Particularly choose owner material. Through hope partner plant tell.
# Nearly computer door adult building article. Choice wide growth source if.
# Month week our ready. Through response both not education data. Opportunity source near family.
# Industry Sector: Edtech
# Total Funding Raised (INR): ₹193 Cr
# Number of Funding Rounds: 4
# Latest Funding Round Type: Series A
# Latest Funding Date: 2023-01-13
# Lead Investors: Kelley-Murphy
# Revenue Estimate (Annual): ₹59 Cr
# Valuation Estimate (if available): ₹674 Cr
# Number of Employees (Current): 301
# Number of Employees (Estimate Range): 200-1335
# Key People: CEO: Mitchell Wallace, CTO: Lucas Jackson
# Founders: Randy Snyder (https://linkedin.com/in/allison39)
# Board Members / Advisors: Sherry Moran
# Employee Growth (YoY %): 50%
# Hiring Status: Actively Hiring
# Popular Roles Open: Marketing, Product
# Primary Products / Services: Prescription Medicines
# Product Categories: SaaS
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: Flipkart, Tata Group
# Press Mentions / Recent News: Them thought blood hard energy deep.
# Competitors: Startup A, Startup B
# 📏 Score: 0.4179
#
# 🔹 Result #5
# 📄 Content:
# Company Name: Mobikwik
# Legal Entity Type: Public Ltd
# State: Rajasthan
# Headquarters City: Mumbai
# Year Founded: 2002
# Company Website: https://adams,haleandlittle.in
# Logo URL: https://logo.clearbit.com/adams,haleandlittle.in
# Company Description (Short): Multi-channeled heuristic concept
# Company Description (Long): Really may go enough hundred. Court throw because candidate.
# End pattern until. Contain capital hand attorney these international drug.
# Daughter technology technology care federal successful woman. Side third government serve summer listen price. Deal size bad.
# Industry Sector: Edtech
# Total Funding Raised (INR): ₹392 Cr
# Number of Funding Rounds: 1
# Latest Funding Round Type: Pre-seed
# Latest Funding Date: 2021-07-25
# Lead Investors: Nichols-Parker
# Revenue Estimate (Annual): ₹246 Cr
# Valuation Estimate (if available): ₹1226 Cr
# Number of Employees (Current): 474
# Number of Employees (Estimate Range): 148-1844
# Key People: CEO: Elizabeth Rose, CTO: Wayne Grimes
# Founders: Diana Harris (https://linkedin.com/in/allenjohn)
# Board Members / Advisors: Jacob Park
# Employee Growth (YoY %): 8%
# Hiring Status: Hiring Freeze
# Popular Roles Open: Sales, Product
# Primary Products / Services: Food Delivery
# Product Categories: D2C
# Tech Stack: Python, React, AWS
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: SMBs
# Major Customers / Logos: Local Kirana Stores
# Press Mentions / Recent News: Skill air poor window.
# Competitors: Startup A, Startup B
# 📏 Score: 0.4187
#
# 🔹 Result #6
# 📄 Content:
# Company Name: Delhivery
# Legal Entity Type: Public Ltd
# State: Telangana
# Headquarters City: Bengaluru
# Year Founded: 2020
# Company Website: https://edwards-cordova.in
# Logo URL: https://logo.clearbit.com/edwards-cordova.in
# Company Description (Short): Innovative even-keeled Internet solution
# Company Description (Long): Dog tax manager important. Family professor score fish run network debate way. Wish consumer develop agreement. Throw close network.
# Interesting look traditional to rest. Threat meeting which fish very environmental my.
# Industry Sector: E-commerce
# Total Funding Raised (INR): ₹222 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Pre-seed
# Latest Funding Date: 2020-01-31
# Lead Investors: Sullivan, Williams and Avery
# Revenue Estimate (Annual): ₹205 Cr
# Valuation Estimate (if available): ₹563 Cr
# Number of Employees (Current): 151
# Number of Employees (Estimate Range): 491-1848
# Key People: CEO: Tracy Bridges, CTO: Margaret Cooper
# Founders: Courtney Moon (https://linkedin.com/in/jessicaflowers)
# Board Members / Advisors: Richard Pham
# Employee Growth (YoY %): 9%
# Hiring Status: Actively Hiring
# Popular Roles Open: Sales, Marketing
# Primary Products / Services: Insurance Platform
# Product Categories: SaaS
# Tech Stack: Node.js, MongoDB, Azure
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Consumers
# Major Customers / Logos: Direct Consumers
# Press Mentions / Recent News: Fish sell piece certainly.
# Competitors: Ecom Express, Xpressbees
# 📏 Score: 0.4206
#
# 🔹 Result #7
# 📄 Content:
# Company Name: Delhivery
# Legal Entity Type: Public Ltd
# State: Delhi
# Headquarters City: Jaipur
# Year Founded: 2014
# Company Website: https://smith,taylorandperkins.in
# Logo URL: https://logo.clearbit.com/smith,taylorandperkins.in
# Company Description (Short): Down-sized dynamic approach
# Company Description (Long): Financial Mrs with amount eight society change success.
# Than suggest order industry with identify. Toward action perform back past manage enough rich. Street great according control girl ground.
# Mr now region interview garden thought eye. Happy already woman store. Live base big car receive.
# Industry Sector: Fintech
# Total Funding Raised (INR): ₹32 Cr
# Number of Funding Rounds: 3
# Latest Funding Round Type: Series C
# Latest Funding Date: 2020-03-07
# Lead Investors: Johnson, Norton and Hall
# Revenue Estimate (Annual): ₹273 Cr
# Valuation Estimate (if available): ₹714 Cr
# Number of Employees (Current): 186
# Number of Employees (Estimate Range): 216-1470
# Key People: CEO: Lisa Dixon, CTO: Karen Hardin
# Founders: Allison Fisher (https://linkedin.com/in/millerterry)
# Board Members / Advisors: Sandra Lopez
# Employee Growth (YoY %): 3%
# Hiring Status: Hiring Freeze
# Popular Roles Open: Product, Marketing
# Primary Products / Services: Food Delivery
# Product Categories: SaaS
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Enterprises
# Major Customers / Logos: HDFC Bank, Airtel
# Press Mentions / Recent News: Similar mind base.
# Competitors: Ecom Express, Xpressbees
# 📏 Score: 0.4208
#
# 🔹 Result #8
# 📄 Content:
# Company Name: Freshworks
# Legal Entity Type: Pvt Ltd
# State: Karnataka
# Headquarters City: Bengaluru
# Year Founded: 2023
# Company Website: https://davisplc.in
# Logo URL: https://logo.clearbit.com/davisplc.in
# Company Description (Short): Synchronized cohesive application
# Company Description (Long): Size effect part long almost. Evening yet total economy southern family table set.
# Adult such seem.
# None artist morning hotel mouth. Stand kid case guy toward industry.
# Camera specific far field skin mean. Save hard management. Official range key. Eight everything join.
# Industry Sector: AgriTech
# Total Funding Raised (INR): ₹299 Cr
# Number of Funding Rounds: 2
# Latest Funding Round Type: Pre-seed
# Latest Funding Date: 2021-09-06
# Lead Investors: Morgan Ltd
# Revenue Estimate (Annual): ₹276 Cr
# Valuation Estimate (if available): ₹921 Cr
# Number of Employees (Current): 32
# Number of Employees (Estimate Range): 319-932
# Key People: CEO: Jose Blanchard, CTO: Michael Kennedy
# Founders: Isaac Smith (https://linkedin.com/in/brittanygonzales)
# Board Members / Advisors: Emily Hopkins
# Employee Growth (YoY %): 5%
# Hiring Status: Actively Hiring
# Popular Roles Open: Engineering, Sales
# Primary Products / Services: AI Chatbot Tools
# Product Categories: SaaS
# Tech Stack: Node.js, MongoDB, Azure
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: SMBs
# Major Customers / Logos: Local Manufacturers
# Press Mentions / Recent News: Color author ball stay free responsibility lawyer.
# Competitors: Zoho, Salesforce
# 📏 Score: 0.4213
#
# 🔹 Result #9
# 📄 Content:
# Company Name: Razorpay
# Legal Entity Type: Public Ltd
# State: West Bengal
# Headquarters City: Chandigarh
# Year Founded: 2009
# Company Website: https://brennan,thomasandwright.in
# Logo URL: https://logo.clearbit.com/brennan,thomasandwright.in
# Company Description (Short): Cloned methodical Graphical User Interface
# Company Description (Long): Computer century as. Material discuss region attention.
# Politics far night job. Air partner center turn much alone major.
# Trial item down my scientist audience.
# Somebody listen big relate parent road need. Debate beat most former teacher guess. Determine our woman apply institution heart score.
# Industry Sector: AgriTech
# Total Funding Raised (INR): ₹199 Cr
# Number of Funding Rounds: 4
# Latest Funding Round Type: Series A
# Latest Funding Date: 2024-12-17
# Lead Investors: Matthews Inc
# Revenue Estimate (Annual): ₹284 Cr
# Valuation Estimate (if available): ₹1625 Cr
# Number of Employees (Current): 326
# Number of Employees (Estimate Range): 249-1916
# Key People: CEO: Jon Anderson, CTO: Margaret Jones
# Founders: Mary Robertson (https://linkedin.com/in/jennifer72)
# Board Members / Advisors: Jennifer Schneider
# Employee Growth (YoY %): 15%
# Hiring Status: Hiring Freeze
# Popular Roles Open: Marketing, Sales
# Primary Products / Services: Online Grocery
# Product Categories: SaaS
# Tech Stack: Java, Spring Boot, GCP
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Consumers
# Major Customers / Logos: Direct Consumers
# Press Mentions / Recent News: Term student top college talk.
# Competitors: Cashfree, PayU
# 📏 Score: 0.4217
#
# 🔹 Result #10
# 📄 Content:
# Company Name: Flipkart
# Legal Entity Type: LLC
# State: Tamil Nadu
# Headquarters City: Chennai
# Year Founded: 2015
# Company Website: https://washington-davis.in
# Logo URL: https://logo.clearbit.com/washington-davis.in
# Company Description (Short): Multi-tiered national matrix
# Company Description (Long): Want situation establish above young something. Whose read significant name.
# Have national real defense account. Major television right black and. Item response face newspaper whom. Follow one opportunity become.
# Industry Sector: Logistics
# Total Funding Raised (INR): ₹251 Cr
# Number of Funding Rounds: 3
# Latest Funding Round Type: Series B
# Latest Funding Date: 2024-05-14
# Lead Investors: Wilson LLC
# Revenue Estimate (Annual): ₹210 Cr
# Valuation Estimate (if available): ₹927 Cr
# Number of Employees (Current): 180
# Number of Employees (Estimate Range): 94-876
# Key People: CEO: Christopher Rodriguez, CTO: Jamie Wilson
# Founders: Crystal Bernard (https://linkedin.com/in/ifernandez)
# Board Members / Advisors: Stephanie Rocha
# Employee Growth (YoY %): 48%
# Hiring Status: Actively Hiring
# Popular Roles Open: Marketing, Sales
# Primary Products / Services: Ride Hailing
# Product Categories: SaaS
# Tech Stack: Node.js, MongoDB, Azure
# Integrations / APIs offered: Razorpay, Zoho, Tally
# Target Market: Consumers
# Major Customers / Logos: Direct Consumers
# Press Mentions / Recent News: Cold hundred effect easy safe me.
# Competitors: Amazon, Meesho
# 📏 Score: 0.4219
